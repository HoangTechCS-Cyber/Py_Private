# %% [markdown]
# <a href="https://colab.research.google.com/github/HoangTechCS-Cyber/Py_Private/blob/main/opencv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 as cv
import numpy as np

# %% [markdown]
# # 1.Upload file

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-221f5a37-bb56-4bad-9c52-4499796d7ef0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-221f5a37-bb56-4bad-9c52-4499796d7ef0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # Đọc và hiển thị hình ảnh

# %%
import cv2 as cv
img = cv.imread("/content/Avatar.jpg")

#Opencv
#cv.imshow("Avatar", img)
#cv.waitKey(0)
# Matplotib
import matplotlib.pyplot as plt

#chuyen doi tu opencv sang maplotlib
img_plt = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img_plt)
#
plt.title("Avatar")
plt.axis("on") # toa do
plt.show()

    # Lấy kích thước ảnh
height, width, channels = img.shape
print(f"Kích thước ảnh gốc: {width} x {height}")
print(f"Số kênh màu: {channels}")
# Out:
# Kích thước ảnh gốc: 960 x 1280
# Số kênh màu: 3

# %% [markdown]
# # 2.Xử lý ảnh cơ bản

# %% [markdown]
# ## 2.1.Thay đổi kích thước và cắt ảnh
#   - Mục tiêu
#     - Resize ảnh
#     - Cắt ảnh

# %%
# Thay đổi kích thước ảnh
resize_img = cv.resize(img, (960, 1280))  # Resize ảnh thành 960x1280 pixel

# Cắt ảnh
crop_img = img[50:200, 100:300]  # Cắt từ tọa độ (100, 50) đến (300, 200)

# Chuyển đổi ảnh sang RGB để hiển thị đúng màu với Matplotlib
resize_img_rgb = cv.cvtColor(resize_img, cv.COLOR_BGR2RGB)
crop_img_rgb = cv.cvtColor(crop_img, cv.COLOR_BGR2RGB)

# Hiển thị ảnh resize
plt.imshow(resize_img_rgb)
plt.title("Resized Image")
plt.axis("off")
plt.show()

# Hiển thị ảnh crop
plt.imshow(crop_img_rgb)
plt.title("Cropped Image")
plt.axis("off")
plt.show()

# %% [markdown]
# ## 2.2.Hiển thị ảnh xám
# ### 2.2.1. Ảnh xám là gì?
# *Ảnh xám là ảnh chỉ có 1 kênh màu, thay vì 3 kênh màu (BGR hoặc RGB).
# Mỗi pixel trong ảnh xám chỉ chứa giá trị cường độ sáng từ 0 (đen hoàn toàn) đến 255 (trắng hoàn toàn).*
# ### 2.2.2. Các bước thực hiện
# - Chuyển đổi ảnh màu sang ảnh xám:
#   - Sử dụng hàm cv.cvtColor() với tham số cv.COLOR_BGR2GRAY.
#
# - Hiển thị ảnh xám:
#   - Khi hiển thị với Matplotlib, sử dụng tham số cmap='gray' để hiển thị ảnh đúng định dạng xám.
